# %% [markdown]
# # Sea Level Projection - Datasheet Analysis
#
# Charting sea level projections from 2005 to 2150

# %%
import csv
from slp import Projection

projections = []

file = csv.DictReader(open('slp_data.csv'))
for row in file:
    p = Projection(
        row['PSMSL Site'],
        row['PSMSL ID'],
        row['NOAA ID'],
        row['NOAA Name'],
        row['RSL GridNum'],
        row['Lat'],
        row['Long'],
        row['RSL2005 (cm)'],
        row['RSL2020 (cm)'],
        row['RSL2030 (cm)'],
        row['RSL2040 (cm)'],
        row['RSL2050 (cm)'],
        row['RSL2060 (cm)'],
        row['RSL2070 (cm)'],
        row['RSL2080 (cm)'],
        row['RSL2090 (cm)'],
        row['RSL2100 (cm)'],
        row['RSL2110 (cm)'],
        row['RSL2120 (cm)'],
        row['RSL2130 (cm)'],
        row['RSL2140 (cm)'],
        row['RSL2150 (cm)']
    )
    projections.append(p)

print( projections[0] )

# %%
import matplotlib.pyplot as plt
import numpy as np
import uuid

plt.style.use('_mpl-gallery')

def draw_graph(projection):
       # make data:
       x = 0.5 + np.arange(15)
       y = [ 
              projection.rsl2005, 
              projection.rsl2020, 
              projection.rsl2030, 
              projection.rsl2040,
              projection.rsl2050,
              projection.rsl2060,
              projection.rsl2070,
              projection.rsl2080,
              projection.rsl2090,
              projection.rsl2100,
              projection.rsl2110,
              projection.rsl2120,
              projection.rsl2130,
              projection.rsl2140,
              projection.rsl2150
       ]

       # build the plot
       fig, ax = plt.subplots()

       ax.bar(x, y, width=1, edgecolor="white", linewidth=1.5)

       ax.set(xlim=(0, 15), xticks=np.arange(1, 15),
              ylim=(0, 50), yticks=np.arange(start=0, stop=50, step=10))

       plt.xlabel('year')
       plt.ylabel('projected (cm)')
       id = str(uuid.uuid4())
       plt.savefig(f'{projection.noaa_name}_{id}.jpg', bbox_inches='tight', dpi=200)
       print(f'{projection.noaa_name}_{id}.jpg ...saved')

       # plt.show()

for p in projections:
       print(f'projection: {p.lat, p.long}')
       draw_graph(p)
# Out:
# projection: ('', '')
# GMSL_b7247211-b26e-4716-b012-6c1992ca4918.jpg ...saved
# projection: ('', '')
# GMSL_022eec8f-421c-4d2c-a4a8-4e7c2529fa51.jpg ...saved
# projection: ('', '')
# GMSL_986dca35-9de4-4dcf-8e3e-31bea5e163c4.jpg ...saved
# projection: ('', '')
# GMSL_9679bdcd-2129-452b-be71-c41a404a728c.jpg ...saved
# projection: ('', '')
# GMSL_560ca708-23e9-454a-a3fc-5de0a6dd4f0f.jpg ...saved
# projection: ('', '')
# GMSL_0bbf6f27-da62-41c5-815f-151e6d7d76a2.jpg ...saved
# projection: ('', '')
# GMSL_fd3649a1-4283-4c0e-9b61-357a53d3cd0f.jpg ...saved
# projection: ('', '')
# GMSL_ec6f0660-3731-4780-98d5-1cdce70ba854.jpg ...saved
# projection: ('', '')
# GMSL_737feff2-51d6-4591-aafe-3f8b9df7f7f7.jpg ...saved
# projection: ('', '')
# GMSL_7f0236bb-4fd8-43bf-b4f6-23fbdafcc283.jpg ...saved
# projection: ('', '')
# GMSL_69406e9e-fa78-44ad-acd4-f23ace301bf1.jpg ...saved
# projection: ('', '')
# GMSL_3406800f-4727-4e29-8206-a2247c16544c.jpg ...saved
# projection: ('', '')
# ...
